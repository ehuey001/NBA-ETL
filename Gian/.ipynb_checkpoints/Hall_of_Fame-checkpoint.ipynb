# %%
from splinter import Browser
from splinter.exceptions import ElementDoesNotExist
from bs4 import BeautifulSoup

import time
import pandas as pd

# !which chromedriver
# Out:
# /usr/local/bin/chromedriver

# %%
url1 = "https://en.wikipedia.org/wiki/List_of_players_in_the_Naismith_Memorial_Basketball_Hall_of_Fame"

# %%
tables = pd.read_html(url1)
hall = tables[0]
hall.head()
# Out:
#    Year      Inductees Pos.  \
# 0  1959    Chuck Hyatt    G
# 1  1959  Hank Luisetti    F
# 2  1959   George Mikan    C
# 3  1959  John Schommer    G
# 4  1960     Vic Hanson    G
#
#                                         Achievements Ref.
# 0  National championship (Pittsburgh, 1928, 1930)...  [3]
# 1  3 Pacific Coast Conference championships (Stan...  [4]
# 2  All-America (DePaul, 1944–45); All-NBA First-T...  [5]
# 3  Big Ten Championships (Chicago, 1907–09); All-...  [6]
# 4  Helms Foundation Championship (Syracuse, 1926)...  [7]

# %%
list_hall = hall.loc[hall["Year"]>1987, :]
list_of_hof = list_hall["Inductees"].to_list()
list_of_hof
# Out:
# ['Clyde Lovellette',
#  'Bobby McDermott',
#  'Wes Unseld',
#  'William Gates',
#  'K.C. Jones',
#  'Lenny Wilkens',
#  'Dave Bing',
#  'Elvin Hayes',
#  'Neil Johnston',
#  'Earl Monroe',
#  'Nate Archibald',
#  'Dave Cowens',
#  'Harry Gallatin',
#  'Sergei Belov',
#  'Lusia Harris-Stewart',
#  'Connie Hawkins',
#  'Bob Lanier',
#  'Nera White',
#  'Walt Bellamy',
#  'Julius Erving',
#  'Dan Issel',
#  'Dick McGuire',
#  'Ann Meyers',
#  'Calvin Murphy',
#  'Uļjana Semjonova',
#  'Bill Walton',
#  'Carol Blazejowski',
#  'Buddy Jeannette',
#  'Kareem Abdul-Jabbar',
#  'Anne Donovan',
#  'Vern Mikkelsen',
#  'Cheryl Miller',
#  'Krešimir Ćosić',
#  'George Gervin',
#  'Gail Goodrich',
#  'Nancy Lieberman',
#  'David Thompson',
#  'George Yardley',
#  'Joan Crawford',
#  'Denise Curry',
#  'Alex English',
#  'Bailey Howell',
#  'Larry Bird',
#  'Marques Haynes',
#  'Arnie Risen',
#  'Kevin McHale',
#  'Bob McAdoo',
#  'Isiah Thomas',
#  'Moses Malone',
#  'Magic Johnson',
#  'Dražen Petrović',
#  'Dino Meneghin',
#  'Robert Parish',
#  'James Worthy',
#  'Dražen Dalipagić',
#  'Clyde Drexler',
#  'Maurice Stokes',
#  'Lynette Woodard',
#  'Hortencia de Fatima Marcari',
#  'Charles Barkley',
#  'Joe Dumars',
#  'Dominique Wilkins',
#  'Adrian Dantley',
#  'Patrick Ewing',
#  'Hakeem Olajuwon',
#  'Michael Jordan',
#  'David Robinson',
#  'John Stockton',
#  'Cynthia Cooper-Dyke',
#  'Dennis Johnson',
#  'Gus Johnson',
#  'Karl Malone',
#  'Ubiratan Pereira Maciel',
#  'Scottie Pippen',
#  'Dennis Rodman',
#  'Chris Mullin',
#  'Arvydas Sabonis',
#  'Artis Gilmore',
#  'Teresa Edwards',
#  'Goose Tatum',
#  'Mel Daniels',
#  'Katrina McClain',
#  'Reggie Miller',
#  'Ralph Sampson',
#  'Chet Walker',
#  'Jamaal Wilkes',
#  'Roger Brown',
#  'Bernard King',
#  'Gary Payton',
#  'Richie Guerin',
#  'Dawn Staley',
#  'Oscar Schmidt',
#  'Šarūnas Marčiulionis',
#  'Alonzo Mourning',
#  'Mitch Richmond',
#  'Guy Rodgers',
#  'Louie Dampier',
#  'Spencer Haywood',
#  'John Isaacs',
#  'Lisa Leslie',
#  'Dikembe Mutombo',
#  'Jo Jo White',
#  'Yao Ming',
#  'Cumberland Posey',
#  'Sheryl Swoopes',
#  'Zelmo Beaty',
#  "Shaquille O'Neal",
#  'Allen Iverson',
#  'Tracy McGrady',
#  'Nikos Galis',
#  'George McGinnis',
#  'Ray Allen',
#  'Maurice Cheeks',
#  'Grant Hill',
#  'Jason Kidd',
#  'Steve Nash',
#  'Katie Smith',
#  'Tina Thompson',
#  'Ora Mae Washington',
#  'Dino Rađa',
#  'Charlie Scott',
#  'Carl Braun',
#  'Chuck Cooper',
#  'Vlade Divac',
#  'Bobby Jones',
#  'Sidney Moncrief',
#  'Jack Sikma',
#  'Teresa Weatherspoon',
#  'Paul Westphal']

# %%
list_of_hof = ['Jaylen Brown','Clyde Lovellette','Bobby McDermott','Wes Unseld','William Gates','K.C. Jones',
               'Lenny Wilkens','Dave Bing','Elvin Hayes','Neil Johnston','Earl Monroe','Nate Archibald','Dave Cowens',
               'Harry Gallatin','Sergei Belov','Lusia Harris-Stewart','Connie Hawkins','Bob Lanier','Nera White',
               'Walt Bellamy','Julius Erving','Dan Issel','Dick McGuire','Ann Meyers','Calvin Murphy',
               'Uļjana Semjonova','Bill Walton','Carol Blazejowski','Buddy Jeannette','Kareem Abdul-Jabbar',
               'Anne Donovan','Vern Mikkelsen','Cheryl Miller','Krešimir Ćosić','George Gervin','Gail Goodrich',
               'Nancy Lieberman','David Thompson','George Yardley','Joan Crawford','Denise Curry','Alex English',
               'Bailey Howell','Larry Bird','Marques Haynes','Arnie Risen','Kevin McHale','Bob McAdoo','Isiah Thomas',
               'Moses Malone','Magic Johnson','Dražen Petrović','Dino Meneghin','Robert Parish','James Worthy',
               'Dražen Dalipagić','Clyde Drexler','Maurice Stokes','Lynette Woodard','Hortencia de Fatima Marcari',
               'Charles Barkley','Joe Dumars','Dominique Wilkins','Adrian Dantley','Patrick Ewing','Hakeem Olajuwon',
               'Michael Jordan','David Robinson','John Stockton','Cynthia Cooper-Dyke','Dennis Johnson','Gus Johnson',
               'Karl Malone','Ubiratan Pereira Maciel','Scottie Pippen','Dennis Rodman','Chris Mullin',
               'Arvydas Sabonis','Artis Gilmore','Teresa Edwards','Goose Tatum','Mel Daniels','Katrina McClain',
               'Reggie Miller','Ralph Sampson','Chet Walker','Jamaal Wilkes','Roger Brown','Bernard King','Gary Payton',
               'Richie Guerin','Dawn Staley','Oscar Schmidt','Šarūnas Marčiulionis','Alonzo Mourning',
               'Mitch Richmond','Guy Rodgers','Louie Dampier','Spencer Haywood','John Isaacs','Lisa Leslie',
               'Dikembe Mutombo','Jo Jo White','Yao Ming','Cumberland Posey','Sheryl Swoopes','Zelmo Beaty',
               "Shaquille O'Neal",'Allen Iverson','Tracy McGrady','Nikos Galis','George McGinnis','Ray Allen',
               'Maurice Cheeks','Grant Hill','Jason Kidd','Steve Nash','Katie Smith','Tina Thompson',
               'Ora Mae Washington','Dino Rađa','Charlie Scott','Carl Braun','Chuck Cooper','Vlade Divac',
               'Bobby Jones','Sidney Moncrief','Jack Sikma','Teresa Weatherspoon','Paul Westphal']

# %%
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
url = 'https://www.basketball-reference.com/'
browser.visit(url)

# %%
player_totals = pd.DataFrame()

for player in list_of_hof:
    try:
        html = browser.html
        soup = BeautifulSoup(html, 'html.parser')
        browser.find_by_css('.ac-input').first.fill(player)
        browser.find_by_value('Search').first.click()
        if browser.find_link_by_partial_text(player + " ("):
            browser.click_link_by_partial_text(player + " (")
            
            time.sleep(1)

            table = soup.find('table', {'id':'totals'})
            df = pd.read_html(str(table))[0]
            df['Player'] = player

            player_totals = player_totals.append(df, ignore_index = True)
        else:
            time.sleep(1)

            table = soup.find('table', {'id':'totals'})
            df = pd.read_html(str(table))[0]
            df['Player'] = player

            player_totals = player_totals.append(df, ignore_index = True)
    except:
        pass
# Out:
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)

# %%
player_totals
# Out:
#           2P    2P%      2PA     3P    3P%    3PA     AST   Age     BLK  \
# 0        NaN    NaN      NaN    NaN    NaN    NaN    70.0  26.0     NaN
# 1        NaN    NaN      NaN    NaN    NaN    NaN   189.0  27.0     NaN
# 2        NaN    NaN      NaN    NaN    NaN    NaN   253.0  28.0     NaN
# 3        NaN    NaN      NaN    NaN    NaN    NaN   343.0  29.0     NaN
# 4        NaN    NaN      NaN    NaN    NaN    NaN   317.0  30.0     NaN
# 5        NaN    NaN      NaN    NaN    NaN    NaN   407.0  31.0     NaN
# 6        NaN    NaN      NaN    NaN    NaN    NaN   437.0  32.0     NaN
# 7        NaN    NaN      NaN    NaN    NaN    NaN   503.0  33.0     NaN
# 8        NaN    NaN      NaN    NaN    NaN    NaN   389.0  34.0     NaN
# 9        NaN    NaN      NaN    NaN    NaN    NaN  2908.0   NaN     NaN
# 10     930.0  0.447   2082.0    NaN    NaN    NaN   113.0  23.0     NaN
# 11     914.0  0.452   2020.0    NaN    NaN    NaN   162.0  24.0     NaN
# 12     948.0  0.428   2215.0    NaN    NaN    NaN   186.0  25.0     NaN
# 13     832.0  0.434   1918.0    NaN    NaN    NaN   270.0  26.0     NaN
# 14     713.0  0.444   1607.0    NaN    NaN    NaN   127.0  27.0     NaN
# 15     689.0  0.423   1627.0    NaN    NaN    NaN   163.0  28.0   240.0
# 16     739.0  0.443   1668.0    NaN    NaN    NaN   206.0  29.0   187.0
# 17     649.0  0.470   1381.0    NaN    NaN    NaN   121.0  30.0   202.0
# 18     760.0  0.501   1516.0    NaN    NaN    NaN   158.0  31.0   220.0
# 19     636.0  0.451   1409.0    NaN    NaN    NaN   149.0  32.0   159.0
# 20     720.0  0.487   1477.0    NaN    NaN    NaN   143.0  33.0   190.0
# 21     758.0  0.456   1664.0    3.0  0.231   13.0   129.0  34.0   189.0
# 22     584.0  0.454   1286.0    0.0  0.000   10.0    98.0  35.0   171.0
# 23     519.0  0.474   1095.0    0.0  0.000    5.0   144.0  36.0   104.0
# 24     422.0  0.476    886.0    2.0  0.500    4.0   158.0  37.0    81.0
# 25     158.0  0.408    387.0    0.0  0.000    2.0    71.0  38.0    28.0
# 26   10971.0  0.453  24238.0    5.0  0.147   34.0  2398.0   NaN  1771.0
# 27       NaN    NaN      NaN    NaN    NaN    NaN     NaN   NaN     NaN
# 28    6248.0  0.458  13635.0    3.0  0.130   23.0  1294.0   NaN  1558.0
# 29    4723.0  0.445  10603.0    2.0  0.182   11.0  1104.0   NaN   213.0
# ..       ...    ...      ...    ...    ...    ...     ...   ...     ...
# 97     512.0  0.486   1053.0    9.0  0.281   32.0   248.0  35.0    82.0
# 98     386.0  0.484    797.0   14.0  0.264   53.0   191.0  36.0    94.0
# 99   11684.0  0.510  22921.0  134.0  0.298  449.0  5176.0   NaN  1941.0
# 100   7191.0  0.510  14100.0   46.0  0.261  176.0  3224.0   NaN  1293.0
# 101   4493.0  0.509   8821.0   88.0  0.322  273.0  1952.0   NaN   648.0
# 102      NaN    NaN      NaN    NaN    NaN    NaN     NaN   NaN     NaN
# 103   7191.0  0.510  14100.0   46.0  0.261  176.0  3224.0   NaN  1293.0
# 104   2697.0  0.516   5231.0   80.0  0.343  233.0  1319.0   NaN   521.0
# 105   1796.0  0.500   3590.0    8.0  0.200   40.0   633.0   NaN   127.0
# 106    938.0  0.489   1919.0    0.0  0.000   15.0   162.0  22.0     NaN
# 107    969.0  0.487   1990.0    3.0  0.273   11.0   195.0  23.0     NaN
# 108    899.0  0.516   1742.0    3.0  0.200   15.0   220.0  24.0     NaN
# 109    826.0  0.483   1709.0    3.0  0.176   17.0   137.0  25.0    32.0
# 110    614.0  0.473   1298.0    0.0  0.000    5.0   188.0  26.0    48.0
# 111    751.0  0.512   1468.0    1.0  0.250    4.0   201.0  27.0    56.0
# 112    660.0  0.515   1282.0    NaN    NaN    NaN   177.0  28.0    29.0
# 113    659.0  0.512   1287.0    NaN    NaN    NaN   304.0  29.0    41.0
# 114    532.0  0.517   1030.0    NaN    NaN    NaN   255.0  30.0    46.0
# 115    711.0  0.506   1404.0    4.0  0.333   12.0   198.0  31.0    54.0
# 116    612.0  0.507   1208.0    2.0  0.167   12.0   158.0  32.0    53.0
# 117    647.0  0.526   1230.0    4.0  0.667    6.0   179.0  33.0    55.0
# 118    657.0  0.514   1277.0    4.0  0.211   19.0   223.0  34.0    43.0
# 119    565.0  0.498   1134.0    4.0  0.211   19.0   173.0  35.0    44.0
# 120    362.0  0.462    784.0    1.0  0.143    7.0   137.0  36.0    31.0
# 121  10402.0  0.501  20762.0   29.0  0.204  142.0  2907.0   NaN   532.0
# 122   5405.0  0.508  10636.0   19.0  0.253   75.0  1804.0   NaN   396.0
# 123   4997.0  0.493  10126.0   10.0  0.149   67.0  1103.0   NaN   136.0
# 124      NaN    NaN      NaN    NaN    NaN    NaN     NaN   NaN     NaN
# 125   6156.0  0.509  12104.0   20.0  0.253   79.0  2005.0   NaN   452.0
# 126   4246.0  0.490   8658.0    9.0  0.143   63.0   902.0   NaN    80.0
#
#         DRB  ...      PF      PTS         Player  Pos     STL      Season  \
# 0       NaN  ...    58.0    171.0  Lenny Wilkens   PG     NaN     1958-59
# 1       NaN  ...   109.0    466.0  Lenny Wilkens   PG     NaN     1959-60
# 2       NaN  ...   190.0    592.0  Lenny Wilkens   PG     NaN     1960-61
# 3       NaN  ...   206.0    735.0  Lenny Wilkens   PG     NaN     1961-62
# 4       NaN  ...   221.0    572.0  Lenny Wilkens   PG     NaN     1962-63
# 5       NaN  ...   253.0    654.0  Lenny Wilkens   PG     NaN     1963-64
# 6       NaN  ...   263.0    649.0  Lenny Wilkens   PG     NaN     1964-65
# 7       NaN  ...   243.0    689.0  Lenny Wilkens   PG     NaN     1965-66
# 8       NaN  ...   273.0    483.0  Lenny Wilkens   PG     NaN     1966-67
# 9       NaN  ...  1816.0   5011.0  Lenny Wilkens  NaN     NaN      Career
# 10      NaN  ...   266.0   2327.0  Neil Johnston    C     NaN     1968-69
# 11      NaN  ...   270.0   2256.0  Neil Johnston    C     NaN     1969-70
# 12      NaN  ...   225.0   2350.0  Neil Johnston    C     NaN     1970-71
# 13      NaN  ...   233.0   2063.0  Neil Johnston    C     NaN     1971-72
# 14      NaN  ...   232.0   1717.0  Neil Johnston   PF     NaN     1972-73
# 15   1109.0  ...   252.0   1735.0  Neil Johnston   PF    86.0     1973-74
# 16    783.0  ...   238.0   1887.0  Neil Johnston   PF   158.0     1974-75
# 17    668.0  ...   293.0   1585.0  Neil Johnston   PF   104.0     1975-76
# 18    740.0  ...   312.0   1942.0  Neil Johnston   PF    87.0     1976-77
# 19    740.0  ...   313.0   1598.0  Neil Johnston   PF    96.0     1977-78
# 20    682.0  ...   308.0   1789.0  Neil Johnston   PF    75.0     1978-79
# 21    627.0  ...   309.0   1859.0  Neil Johnston   PF    62.0     1979-80
# 22    554.0  ...   300.0   1439.0  Neil Johnston   PF    68.0     1980-81
# 23    480.0  ...   287.0   1318.0  Neil Johnston   PF    62.0     1981-82
# 24    417.0  ...   232.0   1046.0  Neil Johnston   PF    50.0     1982-83
# 25    173.0  ...   123.0    402.0  Neil Johnston   PF    16.0     1983-84
# 26   6973.0  ...  4193.0  27313.0  Neil Johnston  NaN   864.0      Career
# 27      NaN  ...     NaN      NaN  Neil Johnston  NaN     NaN         NaN
# 28   5903.0  ...  2557.0  15551.0  Neil Johnston  NaN   736.0   9 seasons
# 29   1070.0  ...  1636.0  11762.0  Neil Johnston  NaN   128.0   7 seasons
# ..      ...  ...     ...      ...            ...  ...     ...         ...
# 97    201.0  ...   196.0   1340.0      Dan Issel   SF   113.0     1985-86
# 98    149.0  ...   137.0   1005.0      Dan Issel   SF    76.0     1986-87
# 99   6836.0  ...  3494.0  30026.0      Dan Issel  NaN  2272.0      Career
# 100  3534.0  ...  2286.0  18364.0      Dan Issel  NaN  1508.0         NaN
# 101  3302.0  ...  1208.0  11662.0      Dan Issel  NaN   764.0         NaN
# 102     NaN  ...     NaN      NaN      Dan Issel  NaN     NaN         NaN
# 103  3534.0  ...  2286.0  18364.0      Dan Issel  NaN  1508.0  11 seasons
# 104  1854.0  ...   747.0   7104.0      Dan Issel  NaN   583.0   3 seasons
# 105  1448.0  ...   461.0   4558.0      Dan Issel  NaN   181.0   2 seasons
# 106   672.0  ...   323.0   2480.0   Dick McGuire    C     NaN     1970-71
# 107   578.0  ...   242.0   2538.0   Dick McGuire   PF     NaN     1971-72
# 108   593.0  ...   255.0   2292.0   Dick McGuire   PF     NaN     1972-73
# 109   501.0  ...   199.0   2118.0   Dick McGuire   PF    69.0     1973-74
# 110   452.0  ...   197.0   1465.0   Dick McGuire   PF    76.0     1974-75
# 111   620.0  ...   266.0   1930.0   Dick McGuire    C   100.0     1975-76
# 112   485.0  ...   246.0   1765.0   Dick McGuire    C    91.0     1976-77
# 113   577.0  ...   279.0   1746.0   Dick McGuire    C   100.0     1977-78
# 114   498.0  ...   233.0   1380.0   Dick McGuire    C    61.0     1978-79
# 115   483.0  ...   190.0   1951.0   Dick McGuire    C    88.0     1979-80
# 116   447.0  ...   249.0   1749.0   Dick McGuire    C    83.0     1980-81
# 117   434.0  ...   245.0   1852.0   Dick McGuire    C    67.0     1981-82
# 118   445.0  ...   227.0   1726.0   Dick McGuire    C    83.0     1982-83
# 119   401.0  ...   182.0   1506.0   Dick McGuire    C    60.0     1983-84
# 120   251.0  ...   171.0    984.0   Dick McGuire    C    65.0     1984-85
# 121  7437.0  ...  3504.0  27482.0   Dick McGuire  NaN   943.0      Career
# 122  4021.0  ...  2022.0  14659.0   Dick McGuire  NaN   698.0         NaN
# 123  3416.0  ...  1482.0  12823.0   Dick McGuire  NaN   245.0         NaN
# 124     NaN  ...     NaN      NaN   Dick McGuire  NaN     NaN         NaN
# 125  4641.0  ...  2288.0  16589.0   Dick McGuire  NaN   798.0  10 seasons
# 126  2796.0  ...  1216.0  10893.0   Dick McGuire  NaN   145.0   5 seasons
#
#         TOV      TRB           Tm   eFG%
# 0       NaN    127.0          BOS    NaN
# 1       NaN    199.0          BOS    NaN
# 2       NaN    279.0          BOS    NaN
# 3       NaN    298.0          BOS    NaN
# 4       NaN    263.0          BOS    NaN
# 5       NaN    372.0          BOS    NaN
# 6       NaN    318.0          BOS    NaN
# 7       NaN    304.0          BOS    NaN
# 8       NaN    239.0          BOS    NaN
# 9       NaN   2399.0          NaN    NaN
# 10      NaN   1406.0          SDR  0.447
# 11      NaN   1386.0          SDR  0.452
# 12      NaN   1362.0          SDR  0.428
# 13      NaN   1197.0          HOU  0.434
# 14      NaN   1177.0          BAL  0.444
# 15      NaN   1463.0          CAP  0.423
# 16      NaN   1004.0          WSB  0.443
# 17      NaN    878.0          WSB  0.470
# 18      NaN   1029.0          WSB  0.501
# 19    229.0   1075.0          WSB  0.451
# 20    235.0    994.0          WSB  0.487
# 21    215.0    896.0          WSB  0.455
# 22    189.0    789.0          WSB  0.451
# 23    208.0    747.0          HOU  0.472
# 24    200.0    616.0          HOU  0.478
# 25     82.0    260.0          HOU  0.406
# 26   1358.0  16279.0          NaN  0.452
# 27      NaN      NaN          NaN    NaN
# 28    868.0   9305.0  BAL,CAP,WSB  0.458
# 29    490.0   6974.0      SDR,HOU  0.445
# ..      ...      ...          ...    ...
# 97    214.0    370.0          PHI  0.484
# 98    158.0    264.0          PHI  0.479
# 99   3940.0  10525.0          NaN  0.509
# 100  2323.0   5601.0          NaN  0.509
# 101  1617.0   4924.0          NaN  0.509
# 102     NaN      NaN          NaN    NaN
# 103  2323.0   5601.0          PHI  0.509
# 104   949.0   2738.0          NYA  0.516
# 105   668.0   2186.0          VIR  0.498
# 106   221.0   1093.0          KEN  0.485
# 107   244.0    931.0          KEN  0.487
# 108   216.0    922.0          KEN  0.514
# 109   171.0    847.0          KEN  0.481
# 110   157.0    710.0          KEN  0.471
# 111   200.0    923.0          DNA  0.511
# 112     NaN    696.0          DEN  0.515
# 113   259.0    830.0          DEN  0.512
# 114   171.0    738.0          DEN  0.517
# 115   163.0    719.0          DEN  0.506
# 116   130.0    676.0          DEN  0.504
# 117   169.0    608.0          DEN  0.528
# 118   174.0    596.0          DEN  0.512
# 119   122.0    513.0          DEN  0.495
# 120    93.0    331.0          DEN  0.460
# 121  2490.0  11133.0          NaN  0.500
# 122  1281.0   5707.0          NaN  0.507
# 123  1209.0   5426.0          NaN  0.492
# 124     NaN      NaN          NaN    NaN
# 125  1481.0   6630.0      DNA,DEN  0.508
# 126  1009.0   4503.0          KEN  0.488
#
# [127 rows x 31 columns]

# %%
player_totals.to_csv('Outputs/HOF_stats.csv', encoding='utf-8')
